# %% [markdown]
# ![Screenshot 2026-02-24 124323.png](data:image/png;base64,...)
#   - =IF(B5>=40,"Pass","Fail")
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - =IF(AND(B16>40000,C16>=90),"Bonus","No Bonus")
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - =IF(B26>=90,"A",IF(B26>=75,"B",IF(B26>=50,"C","Fail")))
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - The Department of Employee ID E103 is Finance.
#   - We use VLOOKUP function. This is because:
#   - The Employee ID is in the first column.
#   - We want to find the Department, which is in the third column.
#   - The data is arranged vertically (top to bottom), and Vlookup is used when data is in columns(vertical).
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - Formula : = =VLOOKUP(B59,A52:B55,2,TRUE) , here B59 = 45000
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - Formula : =IF(B66>C66,"Exceeded","OK")
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - =INDEX(B73:B76,MATCH("E105",A73:A76,0))
#   - ![image.png](data:image/png;base64,...)
#   - Salary of EmpID = 72000

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   - Formula : =XLOOKUP("E303",A85:A88,B85:B88)
#   - ![image.png](data:image/png;base64,...)
